# %%
# !pip install mokuro

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# See https://github.com/kha-white/mokuro#usage for instructions on setting parameters

# %%
# !mokuro --parent_dir "/content/drive/MyDrive/manga/UchiNoNyan'sDiary"
# Out:
# 2026-03-18 14:29:44.312 | WARNING  | mokuro.run:run:55 - Legacy HTML output is deprecated and will not be further developed. It's recommended to use .mokuro format and web reader instead. Legacy HTML will be disabled by default in the future. To explicitly enable it, run with option --legacy-html.
# 2026-03-18 14:29:44.313 | INFO     | mokuro.run:run:63 - Scanning paths...
#
# Found 1 volumes:
#
# /content/drive/MyDrive/Mokuro OCRs/Chainsaw-Man/DLRAW.AC_Chensoman color v01-11.zip (unprocessed)
#
# Each of the paths above will be treated as one volume.
#
#
# Continue? [yes/no]yes
# 2026-03-18 14:29:48.281 | INFO     | mokuro.run:run:133 - Processing 1/1: /content/drive/MyDrive/Mokuro OCRs/Chainsaw-Man/DLRAW.AC_Chensoman color v01-11.zip
# 2026-03-18 14:29:48.282 | INFO     | mokuro.volume:unzip:121 - Unzipping /content/drive/MyDrive/Mokuro OCRs/Chainsaw-Man/DLRAW.AC_Chensoman color v01-11.zip
# Processing pages...:   0% 0/2194 [00:00<?, ?it/s]2026-03-18 14:30:33.286 | INFO     | mokuro.manga_page_ocr:__init__:41 - Initializing text detector, using device cuda
# 2026-03-18 14:30:33.286 | INFO     | mokuro.cache:_download_if_needed:23 - Downloading https://github.com/zyddnys/manga-image-translator/releases/download/beta-0.2.1/comictextdetector.pt
# 2026-03-18 14:30:36.454 | INFO     | mokuro.cache:_download_if_needed:31 - Finished downloading https://github.com/zyddnys/manga-image-translator/releases/download/beta-0.2.1/comictextdetector.pt
# 2026-03-18 14:30:37.652 | INFO     | manga_ocr.ocr:__init__:16 - Loading OCR model from kha-white/manga-ocr-base
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# preprocessor_config.json: 100% 228/228 [00:00<00:00, 1.41MB/s]
#
# config.json: 77.5kB [00:00, 65.8MB/s]
#
# tokenizer_config.json: 100% 486/486 [00:00<00:00, 2.79MB/s]
#
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 794kB/s]
#
# vocab.txt: 24.1kB [00:00, 55.7MB/s]
#
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:01<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:01<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:01<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:01<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:01<?, ?B/s]
# pytorch_model.bin:   0% 0.00/444M [00:02<?, ?B/s]
# pytorch_model.bin:   0% 24.5k/444M [00:02<1:00:31, 122kB/s]
# pytorch_model.bin:  30% 134M/444M [00:03<00:02, 142MB/s]
# pytorch_model.bin:  58% 256M/444M [00:03<00:00, 204MB/s]
# pytorch_model.bin:  63% 278M/444M [00:03<00:00, 184MB/s]
# pytorch_model.bin:  78% 345M/444M [00:03<00:00, 220MB/s]
# pytorch_model.bin:  93% 412M/444M [00:04<00:00, 249MB/s]
# pytorch_model.bin: 100% 444M/444M [00:04<00:00, 90.0MB/s]
#
# Loading weights:   0% 0/264 [00:00<?, ?it/s]
# Loading weights:   0% 1/264 [00:00<00:00, 10866.07it/s, Materializing param=decoder.bert.embeddings.LayerNorm.bias]
# Loading weights:   0% 1/264 [00:00<00:00, 4877.10it/s, Materializing param=decoder.bert.embeddings.LayerNorm.bias]
# Loading weights:   1% 2/264 [00:00<00:00, 4350.94it/s, Materializing param=decoder.bert.embeddings.LayerNorm.weight]
# Loading weights:   1% 2/264 [00:00<00:00, 3446.43it/s, Materializing param=decoder.bert.embeddings.LayerNorm.weight]
# Loading weights:   1% 3/264 [00:00<00:00, 3777.52it/s, Materializing param=decoder.bert.embeddings.position_embeddings.weight]
# Loading weights:   1% 3/264 [00:00<00:00, 3327.05it/s, Materializing param=decoder.bert.embeddings.position_embeddings.weight]
# Loading weights:   2% 4/264 [00:00<00:00, 3652.78it/s, Materializing param=decoder.bert.embeddings.token_type_embeddings.weight]
# Loading weights:   2% 4/264 [00:00<00:00, 3337.42it/s, Materializing param=decoder.bert.embeddings.token_type_embeddings.weight]
# Loading weights:   2% 5/264 [00:00<00:00, 3597.79it/s, Materializing param=decoder.bert.embeddings.word_embeddings.weight]
# Loading weights:   2% 5/264 [00:00<00:00, 3343.67it/s, Materializing param=decoder.bert.embeddings.word_embeddings.weight]
# Loading weights:   2% 6/264 [00:00<00:00, 3589.99it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   2% 6/264 [00:00<00:00, 3378.87it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   3% 7/264 [00:00<00:00, 3560.53it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   3% 7/264 [00:00<00:00, 3379.78it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   3% 8/264 [00:00<00:00, 3526.85it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.dense.bias]
# Loading weights:   3% 8/264 [00:00<00:00, 3380.12it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.dense.bias]
# Loading weights:   3% 9/264 [00:00<00:00, 3521.34it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.dense.weight]
# Loading weights:   3% 9/264 [00:00<00:00, 3384.63it/s, Materializing param=decoder.bert.encoder.layer.0.attention.output.dense.weight]
# Loading weights:   4% 10/264 [00:00<00:00, 3520.78it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.key.bias]
# Loading weights:   4% 10/264 [00:00<00:00, 3398.95it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.key.bias]
# Loading weights:   4% 11/264 [00:00<00:00, 3524.09it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.key.weight]
# Loading weights:   4% 11/264 [00:00<00:00, 3413.03it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.key.weight]
# Loading weights:   5% 12/264 [00:00<00:00, 3507.19it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.query.bias]
# Loading weights:   5% 12/264 [00:00<00:00, 3398.49it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.query.bias]
# Loading weights:   5% 13/264 [00:00<00:00, 3490.55it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.query.weight]
# Loading weights:   5% 13/264 [00:00<00:00, 3393.87it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.query.weight]
# Loading weights:   5% 14/264 [00:00<00:00, 3488.40it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.value.bias]
# Loading weights:   5% 14/264 [00:00<00:00, 3401.71it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.value.bias]
# Loading weights:   6% 15/264 [00:00<00:00, 3475.94it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.value.weight]
# Loading weights:   6% 15/264 [00:00<00:00, 3370.54it/s, Materializing param=decoder.bert.encoder.layer.0.attention.self.value.weight]
# Loading weights:   6% 16/264 [00:00<00:00, 3419.91it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.bias]
# Loading weights:   6% 16/264 [00:00<00:00, 3336.43it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.bias]
# Loading weights:   6% 17/264 [00:00<00:00, 3385.39it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.weight]
# Loading weights:   6% 17/264 [00:00<00:00, 3305.82it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.LayerNorm.weight]
# Loading weights:   7% 18/264 [00:00<00:00, 3338.09it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.dense.bias]
# Loading weights:   7% 18/264 [00:00<00:00, 3256.31it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.dense.bias]
# Loading weights:   7% 19/264 [00:00<00:00, 3311.52it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.dense.weight]
# Loading weights:   7% 19/264 [00:00<00:00, 3252.99it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.output.dense.weight]
# Loading weights:   8% 20/264 [00:00<00:00, 3310.68it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.key.bias]
# Loading weights:   8% 20/264 [00:00<00:00, 3255.94it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.key.bias]
# Loading weights:   8% 21/264 [00:00<00:00, 3313.53it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.key.weight]
# Loading weights:   8% 21/264 [00:00<00:00, 3258.25it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.key.weight]
# Loading weights:   8% 22/264 [00:00<00:00, 3313.04it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.query.bias]
# Loading weights:   8% 22/264 [00:00<00:00, 3262.90it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.query.bias]
# Loading weights:   9% 23/264 [00:00<00:00, 3316.80it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.query.weight]
# Loading weights:   9% 23/264 [00:00<00:00, 3268.81it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.query.weight]
# Loading weights:   9% 24/264 [00:00<00:00, 3325.95it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.value.bias]
# Loading weights:   9% 24/264 [00:00<00:00, 3273.18it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.value.bias]
# Loading weights:   9% 25/264 [00:00<00:00, 3315.87it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.value.weight]
# Loading weights:   9% 25/264 [00:00<00:00, 3271.48it/s, Materializing param=decoder.bert.encoder.layer.0.crossattention.self.value.weight]
# Loading weights:  10% 26/264 [00:00<00:00, 3324.25it/s, Materializing param=decoder.bert.encoder.layer.0.intermediate.dense.bias]
# Loading weights:  10% 26/264 [00:00<00:00, 3282.92it/s, Materializing param=decoder.bert.encoder.layer.0.intermediate.dense.bias]
# Loading weights:  10% 27/264 [00:00<00:00, 3334.30it/s, Materializing param=decoder.bert.encoder.layer.0.intermediate.dense.weight]
# Loading weights:  10% 27/264 [00:00<00:00, 3294.82it/s, Materializing param=decoder.bert.encoder.layer.0.intermediate.dense.weight]
# Loading weights:  11% 28/264 [00:00<00:00, 3334.58it/s, Materializing param=decoder.bert.encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  11% 28/264 [00:00<00:00, 3291.86it/s, Materializing param=decoder.bert.encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  11% 29/264 [00:00<00:00, 3313.13it/s, Materializing param=decoder.bert.encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  11% 29/264 [00:00<00:00, 3270.54it/s, Materializing param=decoder.bert.encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  11% 30/264 [00:00<00:00, 3299.57it/s, Materializing param=decoder.bert.encoder.layer.0.output.dense.bias]
# Loading weights:  11% 30/264 [00:00<00:00, 3258.98it/s, Materializing param=decoder.bert.encoder.layer.0.output.dense.bias]
# Loading weights:  12% 31/264 [00:00<00:00, 3285.08it/s, Materializing param=decoder.bert.encoder.layer.0.output.dense.weight]
# Loading weights:  12% 31/264 [00:00<00:00, 3243.85it/s, Materializing param=decoder.bert.encoder.layer.0.output.dense.weight]
# Loading weights:  12% 32/264 [00:00<00:00, 3266.04it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  12% 32/264 [00:00<00:00, 3233.07it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  12% 33/264 [00:00<00:00, 3273.70it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  12% 33/264 [00:00<00:00, 3240.82it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  13% 34/264 [00:00<00:00, 3280.80it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.dense.bias]
# Loading weights:  13% 34/264 [00:00<00:00, 3245.04it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.dense.bias]
# Loading weights:  13% 35/264 [00:00<00:00, 3277.90it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.dense.weight]
# Loading weights:  13% 35/264 [00:00<00:00, 3246.51it/s, Materializing param=decoder.bert.encoder.layer.1.attention.output.dense.weight]
# Loading weights:  14% 36/264 [00:00<00:00, 3284.43it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.key.bias]
# Loading weights:  14% 36/264 [00:00<00:00, 3255.75it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.key.bias]
# Loading weights:  14% 37/264 [00:00<00:00, 3294.33it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.key.weight]
# Loading weights:  14% 37/264 [00:00<00:00, 3266.25it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.key.weight]
# Loading weights:  14% 38/264 [00:00<00:00, 3298.30it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.query.bias]
# Loading weights:  14% 38/264 [00:00<00:00, 3269.67it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.query.bias]
# Loading weights:  15% 39/264 [00:00<00:00, 3301.67it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.query.weight]
# Loading weights:  15% 39/264 [00:00<00:00, 3273.85it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.query.weight]
# Loading weights:  15% 40/264 [00:00<00:00, 3308.14it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.value.bias]
# Loading weights:  15% 40/264 [00:00<00:00, 3282.12it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.value.bias]
# Loading weights:  16% 41/264 [00:00<00:00, 3315.08it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.value.weight]
# Loading weights:  16% 41/264 [00:00<00:00, 3291.29it/s, Materializing param=decoder.bert.encoder.layer.1.attention.self.value.weight]
# Loading weights:  16% 42/264 [00:00<00:00, 3322.41it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.bias]
# Loading weights:  16% 42/264 [00:00<00:00, 3295.13it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.bias]
# Loading weights:  16% 43/264 [00:00<00:00, 3322.74it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.weight]
# Loading weights:  16% 43/264 [00:00<00:00, 3297.05it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.LayerNorm.weight]
# Loading weights:  17% 44/264 [00:00<00:00, 3325.93it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.dense.bias]
# Loading weights:  17% 44/264 [00:00<00:00, 3297.64it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.dense.bias]
# Loading weights:  17% 45/264 [00:00<00:00, 3307.75it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.dense.weight]
# Loading weights:  17% 45/264 [00:00<00:00, 3285.41it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.output.dense.weight]
# Loading weights:  17% 46/264 [00:00<00:00, 3308.04it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.key.bias]
# Loading weights:  17% 46/264 [00:00<00:00, 3282.99it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.key.bias]
# Loading weights:  18% 47/264 [00:00<00:00, 3310.76it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.key.weight]
# Loading weights:  18% 47/264 [00:00<00:00, 3284.50it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.key.weight]
# Loading weights:  18% 48/264 [00:00<00:00, 3313.53it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.query.bias]
# Loading weights:  18% 48/264 [00:00<00:00, 3295.63it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.query.bias]
# Loading weights:  19% 49/264 [00:00<00:00, 3260.48it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.query.weight]
# Loading weights:  19% 49/264 [00:00<00:00, 3242.47it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.query.weight]
# Loading weights:  19% 50/264 [00:00<00:00, 3259.18it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.value.bias]
# Loading weights:  19% 50/264 [00:00<00:00, 3230.46it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.value.bias]
# Loading weights:  19% 51/264 [00:00<00:00, 3248.63it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.value.weight]
# Loading weights:  19% 51/264 [00:00<00:00, 3226.44it/s, Materializing param=decoder.bert.encoder.layer.1.crossattention.self.value.weight]
# Loading weights:  20% 52/264 [00:00<00:00, 3245.98it/s, Materializing param=decoder.bert.encoder.layer.1.intermediate.dense.bias]
# Loading weights:  20% 52/264 [00:00<00:00, 3224.43it/s, Materializing param=decoder.bert.encoder.layer.1.intermediate.dense.bias]
# Loading weights:  20% 53/264 [00:00<00:00, 3240.02it/s, Materializing param=decoder.bert.encoder.layer.1.intermediate.dense.weight]
# Loading weights:  20% 53/264 [00:00<00:00, 3224.75it/s, Materializing param=decoder.bert.encoder.layer.1.intermediate.dense.weight]
# Loading weights:  20% 54/264 [00:00<00:00, 3246.74it/s, Materializing param=decoder.bert.encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  20% 54/264 [00:00<00:00, 3224.83it/s, Materializing param=decoder.bert.encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  21% 55/264 [00:00<00:00, 3238.84it/s, Materializing param=decoder.bert.encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  21% 55/264 [00:00<00:00, 3219.36it/s, Materializing param=decoder.bert.encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  21% 56/264 [00:00<00:00, 3243.94it/s, Materializing param=decoder.bert.encoder.layer.1.output.dense.bias]
# Loading weights:  21% 56/264 [00:00<00:00, 3197.01it/s, Materializing param=decoder.bert.encoder.layer.1.output.dense.bias]
# Loading weights:  22% 57/264 [00:00<00:00, 3214.16it/s, Materializing param=decoder.bert.encoder.layer.1.output.dense.weight]
# Loading weights:  22% 57/264 [00:00<00:00, 3197.43it/s, Materializing param=decoder.bert.encoder.layer.1.output.dense.weight]
# Loading weights:  22% 58/264 [00:00<00:00, 3217.09it/s, Materializing param=decoder.cls.predictions.bias]
# Loading weights:  22% 58/264 [00:00<00:00, 3174.14it/s, Materializing param=decoder.cls.predictions.bias]
# Loading weights:  22% 59/264 [00:00<00:00, 3158.36it/s, Materializing param=decoder.cls.predictions.decoder.bias]
# Loading weights:  22% 59/264 [00:00<00:00, 3139.85it/s, Materializing param=decoder.cls.predictions.decoder.bias]
# Loading weights:  23% 60/264 [00:00<00:00, 3132.57it/s, Materializing param=decoder.cls.predictions.decoder.weight]
# Loading weights:  23% 60/264 [00:00<00:00, 3092.16it/s, Materializing param=decoder.cls.predictions.decoder.weight]
# Loading weights:  23% 61/264 [00:00<00:00, 3090.04it/s, Materializing param=decoder.cls.predictions.transform.LayerNorm.bias]
# Loading weights:  23% 61/264 [00:00<00:00, 3072.97it/s, Materializing param=decoder.cls.predictions.transform.LayerNorm.bias]
# Loading weights:  23% 62/264 [00:00<00:00, 3056.35it/s, Materializing param=decoder.cls.predictions.transform.LayerNorm.weight]
# Loading weights:  23% 62/264 [00:00<00:00, 3039.56it/s, Materializing param=decoder.cls.predictions.transform.LayerNorm.weight]
# Loading weights:  24% 63/264 [00:00<00:00, 812.75it/s, Materializing param=decoder.cls.predictions.transform.dense.bias]
# Loading weights:  24% 63/264 [00:00<00:00, 811.84it/s, Materializing param=decoder.cls.predictions.transform.dense.bias]
# Loading weights:  24% 64/264 [00:00<00:00, 822.85it/s, Materializing param=decoder.cls.predictions.transform.dense.weight]
# Loading weights:  24% 64/264 [00:00<00:00, 821.99it/s, Materializing param=decoder.cls.predictions.transform.dense.weight]
# Loading weights:  25% 65/264 [00:00<00:00, 832.94it/s, Materializing param=encoder.embeddings.cls_token]
# Loading weights:  25% 65/264 [00:00<00:00, 831.90it/s, Materializing param=encoder.embeddings.cls_token]
# Loading weights:  25% 66/264 [00:00<00:00, 842.32it/s, Materializing param=encoder.embeddings.patch_embeddings.projection.bias]
# Loading weights:  25% 66/264 [00:00<00:00, 841.27it/s, Materializing param=encoder.embeddings.patch_embeddings.projection.bias]
# Loading weights:  25% 67/264 [00:00<00:00, 851.98it/s, Materializing param=encoder.embeddings.patch_embeddings.projection.weight]
# Loading weights:  25% 67/264 [00:00<00:00, 850.83it/s, Materializing param=encoder.embeddings.patch_embeddings.projection.weight]
# Loading weights:  26% 68/264 [00:00<00:00, 861.52it/s, Materializing param=encoder.embeddings.position_embeddings]
# Loading weights:  26% 68/264 [00:00<00:00, 860.48it/s, Materializing param=encoder.embeddings.position_embeddings]
# Loading weights:  26% 69/264 [00:00<00:00, 871.38it/s, Materializing param=encoder.encoder.layer.0.attention.attention.key.bias]
# Loading weights:  26% 69/264 [00:00<00:00, 870.33it/s, Materializing param=encoder.encoder.layer.0.attention.attention.key.bias]
# Loading weights:  27% 70/264 [00:00<00:00, 880.61it/s, Materializing param=encoder.encoder.layer.0.attention.attention.key.weight]
# Loading weights:  27% 70/264 [00:00<00:00, 879.47it/s, Materializing param=encoder.encoder.layer.0.attention.attention.key.weight]
# Loading weights:  27% 71/264 [00:00<00:00, 889.88it/s, Materializing param=encoder.encoder.layer.0.attention.attention.query.bias]
# Loading weights:  27% 71/264 [00:00<00:00, 888.93it/s, Materializing param=encoder.encoder.layer.0.attention.attention.query.bias]
# Loading weights:  27% 72/264 [00:00<00:00, 899.45it/s, Materializing param=encoder.encoder.layer.0.attention.attention.query.weight]
# Loading weights:  27% 72/264 [00:00<00:00, 898.59it/s, Materializing param=encoder.encoder.layer.0.attention.attention.query.weight]
# Loading weights:  28% 73/264 [00:00<00:00, 908.79it/s, Materializing param=encoder.encoder.layer.0.attention.attention.value.bias]
# Loading weights:  28% 73/264 [00:00<00:00, 907.74it/s, Materializing param=encoder.encoder.layer.0.attention.attention.value.bias]
# Loading weights:  28% 74/264 [00:00<00:00, 917.89it/s, Materializing param=encoder.encoder.layer.0.attention.attention.value.weight]
# Loading weights:  28% 74/264 [00:00<00:00, 916.64it/s, Materializing param=encoder.encoder.layer.0.attention.attention.value.weight]
# Loading weights:  28% 75/264 [00:00<00:00, 925.53it/s, Materializing param=encoder.encoder.layer.0.attention.output.dense.bias]
# Loading weights:  28% 75/264 [00:00<00:00, 924.34it/s, Materializing param=encoder.encoder.layer.0.attention.output.dense.bias]
# Loading weights:  29% 76/264 [00:00<00:00, 934.40it/s, Materializing param=encoder.encoder.layer.0.attention.output.dense.weight]
# Loading weights:  29% 76/264 [00:00<00:00, 933.07it/s, Materializing param=encoder.encoder.layer.0.attention.output.dense.weight]
# Loading weights:  29% 77/264 [00:00<00:00, 942.69it/s, Materializing param=encoder.encoder.layer.0.intermediate.dense.bias]
# Loading weights:  29% 77/264 [00:00<00:00, 941.47it/s, Materializing param=encoder.encoder.layer.0.intermediate.dense.bias]
# Loading weights:  30% 78/264 [00:00<00:00, 951.34it/s, Materializing param=encoder.encoder.layer.0.intermediate.dense.weight]
# Loading weights:  30% 78/264 [00:00<00:00, 950.23it/s, Materializing param=encoder.encoder.layer.0.intermediate.dense.weight]
# Loading weights:  30% 79/264 [00:00<00:00, 960.43it/s, Materializing param=encoder.encoder.layer.0.layernorm_after.bias]
# Loading weights:  30% 79/264 [00:00<00:00, 959.00it/s, Materializing param=encoder.encoder.layer.0.layernorm_after.bias]
# Loading weights:  30% 80/264 [00:00<00:00, 968.91it/s, Materializing param=encoder.encoder.layer.0.layernorm_after.weight]
# Loading weights:  30% 80/264 [00:00<00:00, 965.92it/s, Materializing param=encoder.encoder.layer.0.layernorm_after.weight]
# Loading weights:  31% 81/264 [00:00<00:00, 974.87it/s, Materializing param=encoder.encoder.layer.0.layernorm_before.bias]
# Loading weights:  31% 81/264 [00:00<00:00, 973.06it/s, Materializing param=encoder.encoder.layer.0.layernorm_before.bias]
# Loading weights:  31% 82/264 [00:00<00:00, 982.07it/s, Materializing param=encoder.encoder.layer.0.layernorm_before.weight]
# Loading weights:  31% 82/264 [00:00<00:00, 980.94it/s, Materializing param=encoder.encoder.layer.0.layernorm_before.weight]
# Loading weights:  31% 83/264 [00:00<00:00, 990.59it/s, Materializing param=encoder.encoder.layer.0.output.dense.bias]
# Loading weights:  31% 83/264 [00:00<00:00, 989.32it/s, Materializing param=encoder.encoder.layer.0.output.dense.bias]
# Loading weights:  32% 84/264 [00:00<00:00, 999.00it/s, Materializing param=encoder.encoder.layer.0.output.dense.weight]
# Loading weights:  32% 84/264 [00:00<00:00, 997.72it/s, Materializing param=encoder.encoder.layer.0.output.dense.weight]
# Loading weights:  32% 85/264 [00:00<00:00, 1006.58it/s, Materializing param=encoder.encoder.layer.1.attention.attention.key.bias]
# Loading weights:  32% 85/264 [00:00<00:00, 1005.23it/s, Materializing param=encoder.encoder.layer.1.attention.attention.key.bias]
# Loading weights:  33% 86/264 [00:00<00:00, 1014.86it/s, Materializing param=encoder.encoder.layer.1.attention.attention.key.weight]
# Loading weights:  33% 86/264 [00:00<00:00, 1013.50it/s, Materializing param=encoder.encoder.layer.1.attention.attention.key.weight]
# Loading weights:  33% 87/264 [00:00<00:00, 1022.33it/s, Materializing param=encoder.encoder.layer.1.attention.attention.query.bias]
# Loading weights:  33% 87/264 [00:00<00:00, 1021.02it/s, Materializing param=encoder.encoder.layer.1.attention.attention.query.bias]
# Loading weights:  33% 88/264 [00:00<00:00, 1029.40it/s, Materializing param=encoder.encoder.layer.1.attention.attention.query.weight]
# Loading weights:  33% 88/264 [00:00<00:00, 1027.88it/s, Materializing param=encoder.encoder.layer.1.attention.attention.query.weight]
# Loading weights:  34% 89/264 [00:00<00:00, 1036.65it/s, Materializing param=encoder.encoder.layer.1.attention.attention.value.bias]
# Loading weights:  34% 89/264 [00:00<00:00, 1035.31it/s, Materializing param=encoder.encoder.layer.1.attention.attention.value.bias]
# Loading weights:  34% 90/264 [00:00<00:00, 1044.15it/s, Materializing param=encoder.encoder.layer.1.attention.attention.value.weight]
# Loading weights:  34% 90/264 [00:00<00:00, 1042.64it/s, Materializing param=encoder.encoder.layer.1.attention.attention.value.weight]
# Loading weights:  34% 91/264 [00:00<00:00, 1051.15it/s, Materializing param=encoder.encoder.layer.1.attention.output.dense.bias]
# Loading weights:  34% 91/264 [00:00<00:00, 1049.75it/s, Materializing param=encoder.encoder.layer.1.attention.output.dense.bias]
# Loading weights:  35% 92/264 [00:00<00:00, 1058.28it/s, Materializing param=encoder.encoder.layer.1.attention.output.dense.weight]
# Loading weights:  35% 92/264 [00:00<00:00, 1056.82it/s, Materializing param=encoder.encoder.layer.1.attention.output.dense.weight]
# Loading weights:  35% 93/264 [00:00<00:00, 1065.89it/s, Materializing param=encoder.encoder.layer.1.intermediate.dense.bias]
# Loading weights:  35% 93/264 [00:00<00:00, 1064.59it/s, Materializing param=encoder.encoder.layer.1.intermediate.dense.bias]
# Loading weights:  36% 94/264 [00:00<00:00, 1073.17it/s, Materializing param=encoder.encoder.layer.1.intermediate.dense.weight]
# Loading weights:  36% 94/264 [00:00<00:00, 1071.53it/s, Materializing param=encoder.encoder.layer.1.intermediate.dense.weight]
# Loading weights:  36% 95/264 [00:00<00:00, 1080.66it/s, Materializing param=encoder.encoder.layer.1.layernorm_after.bias]
# Loading weights:  36% 95/264 [00:00<00:00, 1079.49it/s, Materializing param=encoder.encoder.layer.1.layernorm_after.bias]
# Loading weights:  36% 96/264 [00:00<00:00, 1088.27it/s, Materializing param=encoder.encoder.layer.1.layernorm_after.weight]
# Loading weights:  36% 96/264 [00:00<00:00, 1087.03it/s, Materializing param=encoder.encoder.layer.1.layernorm_after.weight]
# Loading weights:  37% 97/264 [00:00<00:00, 1095.84it/s, Materializing param=encoder.encoder.layer.1.layernorm_before.bias]
# Loading weights:  37% 97/264 [00:00<00:00, 1094.36it/s, Materializing param=encoder.encoder.layer.1.layernorm_before.bias]
# Loading weights:  37% 98/264 [00:00<00:00, 1103.29it/s, Materializing param=encoder.encoder.layer.1.layernorm_before.weight]
# Loading weights:  37% 98/264 [00:00<00:00, 1101.90it/s, Materializing param=encoder.encoder.layer.1.layernorm_before.weight]
# Loading weights:  38% 99/264 [00:00<00:00, 1110.52it/s, Materializing param=encoder.encoder.layer.1.output.dense.bias]
# Loading weights:  38% 99/264 [00:00<00:00, 1109.41it/s, Materializing param=encoder.encoder.layer.1.output.dense.bias]
# Loading weights:  38% 100/264 [00:00<00:00, 1117.87it/s, Materializing param=encoder.encoder.layer.1.output.dense.weight]
# Loading weights:  38% 100/264 [00:00<00:00, 1116.29it/s, Materializing param=encoder.encoder.layer.1.output.dense.weight]
# Loading weights:  38% 101/264 [00:00<00:00, 1125.06it/s, Materializing param=encoder.encoder.layer.2.attention.attention.key.bias]
# Loading weights:  38% 101/264 [00:00<00:00, 1123.64it/s, Materializing param=encoder.encoder.layer.2.attention.attention.key.bias]
# Loading weights:  39% 102/264 [00:00<00:00, 1132.26it/s, Materializing param=encoder.encoder.layer.2.attention.attention.key.weight]
# Loading weights:  39% 102/264 [00:00<00:00, 1130.96it/s, Materializing param=encoder.encoder.layer.2.attention.attention.key.weight]
# Loading weights:  39% 103/264 [00:00<00:00, 1139.16it/s, Materializing param=encoder.encoder.layer.2.attention.attention.query.bias]
# Loading weights:  39% 103/264 [00:00<00:00, 1137.43it/s, Materializing param=encoder.encoder.layer.2.attention.attention.query.bias]
# Loading weights:  39% 104/264 [00:00<00:00, 1145.51it/s, Materializing param=encoder.encoder.layer.2.attention.attention.query.weight]
# Loading weights:  39% 104/264 [00:00<00:00, 1144.47it/s, Materializing param=encoder.encoder.layer.2.attention.attention.query.weight]
# Loading weights:  40% 105/264 [00:00<00:00, 1153.03it/s, Materializing param=encoder.encoder.layer.2.attention.attention.value.bias]
# Loading weights:  40% 105/264 [00:00<00:00, 1151.56it/s, Materializing param=encoder.encoder.layer.2.attention.attention.value.bias]
# Loading weights:  40% 106/264 [00:00<00:00, 1159.19it/s, Materializing param=encoder.encoder.layer.2.attention.attention.value.weight]
# Loading weights:  40% 106/264 [00:00<00:00, 1157.81it/s, Materializing param=encoder.encoder.layer.2.attention.attention.value.weight]
# Loading weights:  41% 107/264 [00:00<00:00, 1165.56it/s, Materializing param=encoder.encoder.layer.2.attention.output.dense.bias]
# Loading weights:  41% 107/264 [00:00<00:00, 1164.20it/s, Materializing param=encoder.encoder.layer.2.attention.output.dense.bias]
# Loading weights:  41% 108/264 [00:00<00:00, 1171.96it/s, Materializing param=encoder.encoder.layer.2.attention.output.dense.weight]
# Loading weights:  41% 108/264 [00:00<00:00, 1170.42it/s, Materializing param=encoder.encoder.layer.2.attention.output.dense.weight]
# Loading weights:  41% 109/264 [00:00<00:00, 1178.43it/s, Materializing param=encoder.encoder.layer.2.intermediate.dense.bias]
# Loading weights:  41% 109/264 [00:00<00:00, 1177.01it/s, Materializing param=encoder.encoder.layer.2.intermediate.dense.bias]
# Loading weights:  42% 110/264 [00:00<00:00, 1184.95it/s, Materializing param=encoder.encoder.layer.2.intermediate.dense.weight]
# Loading weights:  42% 110/264 [00:00<00:00, 1183.32it/s, Materializing param=encoder.encoder.layer.2.intermediate.dense.weight]
# Loading weights:  42% 111/264 [00:00<00:00, 1191.51it/s, Materializing param=encoder.encoder.layer.2.layernorm_after.bias]
# Loading weights:  42% 111/264 [00:00<00:00, 1190.10it/s, Materializing param=encoder.encoder.layer.2.layernorm_after.bias]
# Loading weights:  42% 112/264 [00:00<00:00, 1198.06it/s, Materializing param=encoder.encoder.layer.2.layernorm_after.weight]
# Loading weights:  42% 112/264 [00:00<00:00, 1196.80it/s, Materializing param=encoder.encoder.layer.2.layernorm_after.weight]
# Loading weights:  43% 113/264 [00:00<00:00, 1204.65it/s, Materializing param=encoder.encoder.layer.2.layernorm_before.bias]
# Loading weights:  43% 113/264 [00:00<00:00, 1202.91it/s, Materializing param=encoder.encoder.layer.2.layernorm_before.bias]
# Loading weights:  43% 114/264 [00:00<00:00, 1211.31it/s, Materializing param=encoder.encoder.layer.2.layernorm_before.weight]
# Loading weights:  43% 114/264 [00:00<00:00, 1210.35it/s, Materializing param=encoder.encoder.layer.2.layernorm_before.weight]
# Loading weights:  44% 115/264 [00:00<00:00, 1218.47it/s, Materializing param=encoder.encoder.layer.2.output.dense.bias]
# Loading weights:  44% 115/264 [00:00<00:00, 1216.95it/s, Materializing param=encoder.encoder.layer.2.output.dense.bias]
# Loading weights:  44% 116/264 [00:00<00:00, 1224.63it/s, Materializing param=encoder.encoder.layer.2.output.dense.weight]
# Loading weights:  44% 116/264 [00:00<00:00, 1223.26it/s, Materializing param=encoder.encoder.layer.2.output.dense.weight]
# Loading weights:  44% 117/264 [00:00<00:00, 1230.90it/s, Materializing param=encoder.encoder.layer.3.attention.attention.key.bias]
# Loading weights:  44% 117/264 [00:00<00:00, 1229.53it/s, Materializing param=encoder.encoder.layer.3.attention.attention.key.bias]
# Loading weights:  45% 118/264 [00:00<00:00, 1236.69it/s, Materializing param=encoder.encoder.layer.3.attention.attention.key.weight]
# Loading weights:  45% 118/264 [00:00<00:00, 1235.07it/s, Materializing param=encoder.encoder.layer.3.attention.attention.key.weight]
# Loading weights:  45% 119/264 [00:00<00:00, 1242.66it/s, Materializing param=encoder.encoder.layer.3.attention.attention.query.bias]
# Loading weights:  45% 119/264 [00:00<00:00, 1241.28it/s, Materializing param=encoder.encoder.layer.3.attention.attention.query.bias]
# Loading weights:  45% 120/264 [00:00<00:00, 1249.20it/s, Materializing param=encoder.encoder.layer.3.attention.attention.query.weight]
# Loading weights:  45% 120/264 [00:00<00:00, 1247.87it/s, Materializing param=encoder.encoder.layer.3.attention.attention.query.weight]
# Loading weights:  46% 121/264 [00:00<00:00, 1255.77it/s, Materializing param=encoder.encoder.layer.3.attention.attention.value.bias]
# Loading weights:  46% 121/264 [00:00<00:00, 1254.36it/s, Materializing param=encoder.encoder.layer.3.attention.attention.value.bias]
# Loading weights:  46% 122/264 [00:00<00:00, 1262.31it/s, Materializing param=encoder.encoder.layer.3.attention.attention.value.weight]
# Loading weights:  46% 122/264 [00:00<00:00, 1260.98it/s, Materializing param=encoder.encoder.layer.3.attention.attention.value.weight]
# Loading weights:  47% 123/264 [00:00<00:00, 1268.92it/s, Materializing param=encoder.encoder.layer.3.attention.output.dense.bias]
# Loading weights:  47% 123/264 [00:00<00:00, 1267.62it/s, Materializing param=encoder.encoder.layer.3.attention.output.dense.bias]
# Loading weights:  47% 124/264 [00:00<00:00, 1275.56it/s, Materializing param=encoder.encoder.layer.3.attention.output.dense.weight]
# Loading weights:  47% 124/264 [00:00<00:00, 1273.71it/s, Materializing param=encoder.encoder.layer.3.attention.output.dense.weight]
# Loading weights:  47% 125/264 [00:00<00:00, 1281.09it/s, Materializing param=encoder.encoder.layer.3.intermediate.dense.bias]
# Loading weights:  47% 125/264 [00:00<00:00, 1279.73it/s, Materializing param=encoder.encoder.layer.3.intermediate.dense.bias]
# Loading weights:  48% 126/264 [00:00<00:00, 1287.29it/s, Materializing param=encoder.encoder.layer.3.intermediate.dense.weight]
# Loading weights:  48% 126/264 [00:00<00:00, 1285.95it/s, Materializing param=encoder.encoder.layer.3.intermediate.dense.weight]
# Loading weights:  48% 127/264 [00:00<00:00, 1293.84it/s, Materializing param=encoder.encoder.layer.3.layernorm_after.bias]
# Loading weights:  48% 127/264 [00:00<00:00, 1292.75it/s, Materializing param=encoder.encoder.layer.3.layernorm_after.bias]
# Loading weights:  48% 128/264 [00:00<00:00, 1300.35it/s, Materializing param=encoder.encoder.layer.3.layernorm_after.weight]
# Loading weights:  48% 128/264 [00:00<00:00, 1299.00it/s, Materializing param=encoder.encoder.layer.3.layernorm_after.weight]
# Loading weights:  49% 129/264 [00:00<00:00, 1306.49it/s, Materializing param=encoder.encoder.layer.3.layernorm_before.bias]
# Loading weights:  49% 129/264 [00:00<00:00, 1305.15it/s, Materializing param=encoder.encoder.layer.3.layernorm_before.bias]
# Loading weights:  49% 130/264 [00:00<00:00, 1312.99it/s, Materializing param=encoder.encoder.layer.3.layernorm_before.weight]
# Loading weights:  49% 130/264 [00:00<00:00, 1311.72it/s, Materializing param=encoder.encoder.layer.3.layernorm_before.weight]
# Loading weights:  50% 131/264 [00:00<00:00, 1319.53it/s, Materializing param=encoder.encoder.layer.3.output.dense.bias]
# Loading weights:  50% 131/264 [00:00<00:00, 734.76it/s, Materializing param=encoder.encoder.layer.3.output.dense.bias]
# Loading weights:  50% 132/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.3.output.dense.bias]
# Loading weights:  50% 132/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.3.output.dense.weight]
# Loading weights:  50% 132/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.3.output.dense.weight]
# Loading weights:  50% 133/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.key.bias]
# Loading weights:  50% 133/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.key.bias]
# Loading weights:  51% 134/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.key.weight]
# Loading weights:  51% 134/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.key.weight]
# Loading weights:  51% 135/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.query.bias]
# Loading weights:  51% 135/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.query.bias]
# Loading weights:  52% 136/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.query.weight]
# Loading weights:  52% 136/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.query.weight]
# Loading weights:  52% 137/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.value.bias]
# Loading weights:  52% 137/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.value.bias]
# Loading weights:  52% 138/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.value.weight]
# Loading weights:  52% 138/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.attention.value.weight]
# Loading weights:  53% 139/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.output.dense.bias]
# Loading weights:  53% 139/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.output.dense.bias]
# Loading weights:  53% 140/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.output.dense.weight]
# Loading weights:  53% 140/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.attention.output.dense.weight]
# Loading weights:  53% 141/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.intermediate.dense.bias]
# Loading weights:  53% 141/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.intermediate.dense.bias]
# Loading weights:  54% 142/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.intermediate.dense.weight]
# Loading weights:  54% 142/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.intermediate.dense.weight]
# Loading weights:  54% 143/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_after.bias]
# Loading weights:  54% 143/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_after.bias]
# Loading weights:  55% 144/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_after.weight]
# Loading weights:  55% 144/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_after.weight]
# Loading weights:  55% 145/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_before.bias]
# Loading weights:  55% 145/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_before.bias]
# Loading weights:  55% 146/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_before.weight]
# Loading weights:  55% 146/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.layernorm_before.weight]
# Loading weights:  56% 147/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.output.dense.bias]
# Loading weights:  56% 147/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.output.dense.bias]
# Loading weights:  56% 148/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.output.dense.weight]
# Loading weights:  56% 148/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.4.output.dense.weight]
# Loading weights:  56% 149/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.key.bias]
# Loading weights:  56% 149/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.key.bias]
# Loading weights:  57% 150/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.key.weight]
# Loading weights:  57% 150/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.key.weight]
# Loading weights:  57% 151/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.query.bias]
# Loading weights:  57% 151/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.query.bias]
# Loading weights:  58% 152/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.query.weight]
# Loading weights:  58% 152/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.query.weight]
# Loading weights:  58% 153/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.value.bias]
# Loading weights:  58% 153/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.value.bias]
# Loading weights:  58% 154/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.value.weight]
# Loading weights:  58% 154/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.attention.value.weight]
# Loading weights:  59% 155/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.output.dense.bias]
# Loading weights:  59% 155/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.output.dense.bias]
# Loading weights:  59% 156/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.output.dense.weight]
# Loading weights:  59% 156/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.attention.output.dense.weight]
# Loading weights:  59% 157/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.intermediate.dense.bias]
# Loading weights:  59% 157/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.intermediate.dense.bias]
# Loading weights:  60% 158/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.intermediate.dense.weight]
# Loading weights:  60% 158/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.intermediate.dense.weight]
# Loading weights:  60% 159/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_after.bias]
# Loading weights:  60% 159/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_after.bias]
# Loading weights:  61% 160/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_after.weight]
# Loading weights:  61% 160/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_after.weight]
# Loading weights:  61% 161/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_before.bias]
# Loading weights:  61% 161/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_before.bias]
# Loading weights:  61% 162/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_before.weight]
# Loading weights:  61% 162/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.layernorm_before.weight]
# Loading weights:  62% 163/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.output.dense.bias]
# Loading weights:  62% 163/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.output.dense.bias]
# Loading weights:  62% 164/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.output.dense.weight]
# Loading weights:  62% 164/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.5.output.dense.weight]
# Loading weights:  62% 165/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.key.bias]
# Loading weights:  62% 165/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.key.bias]
# Loading weights:  63% 166/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.key.weight]
# Loading weights:  63% 166/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.key.weight]
# Loading weights:  63% 167/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.query.bias]
# Loading weights:  63% 167/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.query.bias]
# Loading weights:  64% 168/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.query.weight]
# Loading weights:  64% 168/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.query.weight]
# Loading weights:  64% 169/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.value.bias]
# Loading weights:  64% 169/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.value.bias]
# Loading weights:  64% 170/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.value.weight]
# Loading weights:  64% 170/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.attention.value.weight]
# Loading weights:  65% 171/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.output.dense.bias]
# Loading weights:  65% 171/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.output.dense.bias]
# Loading weights:  65% 172/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.output.dense.weight]
# Loading weights:  65% 172/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.attention.output.dense.weight]
# Loading weights:  66% 173/264 [00:00<00:00, 739.43it/s, Materializing param=encoder.encoder.layer.6.intermediate.dense.bias]
# ...
# Loading weights:  80% 210/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.8.layernorm_before.weight]
# Loading weights:  80% 211/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.8.output.dense.bias]
# Loading weights:  80% 211/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.8.output.dense.bias]
# Loading weights:  80% 212/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.8.output.dense.weight]
# Loading weights:  80% 212/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.8.output.dense.weight]
# Loading weights:  81% 213/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.key.bias]
# Loading weights:  81% 213/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.key.bias]
# Loading weights:  81% 214/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.key.weight]
# Loading weights:  81% 214/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.key.weight]
# Loading weights:  81% 215/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.query.bias]
# Loading weights:  81% 215/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.query.bias]
# Loading weights:  82% 216/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.query.weight]
# Loading weights:  82% 216/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.query.weight]
# Loading weights:  82% 217/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.value.bias]
# Loading weights:  82% 217/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.value.bias]
# Loading weights:  83% 218/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.value.weight]
# Loading weights:  83% 218/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.attention.value.weight]
# Loading weights:  83% 219/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.output.dense.bias]
# Loading weights:  83% 219/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.output.dense.bias]
# Loading weights:  83% 220/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.output.dense.weight]
# Loading weights:  83% 220/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.attention.output.dense.weight]
# Loading weights:  84% 221/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.intermediate.dense.bias]
# Loading weights:  84% 221/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.intermediate.dense.bias]
# Loading weights:  84% 222/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.intermediate.dense.weight]
# Loading weights:  84% 222/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.intermediate.dense.weight]
# Loading weights:  84% 223/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_after.bias]
# Loading weights:  84% 223/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_after.bias]
# Loading weights:  85% 224/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_after.weight]
# Loading weights:  85% 224/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_after.weight]
# Loading weights:  85% 225/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_before.bias]
# Loading weights:  85% 225/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_before.bias]
# Loading weights:  86% 226/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_before.weight]
# Loading weights:  86% 226/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.layernorm_before.weight]
# Loading weights:  86% 227/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.output.dense.bias]
# Loading weights:  86% 227/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.output.dense.bias]
# Loading weights:  86% 228/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.output.dense.weight]
# Loading weights:  86% 228/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.9.output.dense.weight]
# Loading weights:  87% 229/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.key.bias]
# Loading weights:  87% 229/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.key.bias]
# Loading weights:  87% 230/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.key.weight]
# Loading weights:  87% 230/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.key.weight]
# Loading weights:  88% 231/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.query.bias]
# Loading weights:  88% 231/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.query.bias]
# Loading weights:  88% 232/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.query.weight]
# Loading weights:  88% 232/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.query.weight]
# Loading weights:  88% 233/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.value.bias]
# Loading weights:  88% 233/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.value.bias]
# Loading weights:  89% 234/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.value.weight]
# Loading weights:  89% 234/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.attention.value.weight]
# Loading weights:  89% 235/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.output.dense.bias]
# Loading weights:  89% 235/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.output.dense.bias]
# Loading weights:  89% 236/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.output.dense.weight]
# Loading weights:  89% 236/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.attention.output.dense.weight]
# Loading weights:  90% 237/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.intermediate.dense.bias]
# Loading weights:  90% 237/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.intermediate.dense.bias]
# Loading weights:  90% 238/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.intermediate.dense.weight]
# Loading weights:  90% 238/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.intermediate.dense.weight]
# Loading weights:  91% 239/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_after.bias]
# Loading weights:  91% 239/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_after.bias]
# Loading weights:  91% 240/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_after.weight]
# Loading weights:  91% 240/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_after.weight]
# Loading weights:  91% 241/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_before.bias]
# Loading weights:  91% 241/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_before.bias]
# Loading weights:  92% 242/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_before.weight]
# Loading weights:  92% 242/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.layernorm_before.weight]
# Loading weights:  92% 243/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.output.dense.bias]
# Loading weights:  92% 243/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.output.dense.bias]
# Loading weights:  92% 244/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.output.dense.weight]
# Loading weights:  92% 244/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.10.output.dense.weight]
# Loading weights:  93% 245/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.key.bias]
# Loading weights:  93% 245/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.key.bias]
# Loading weights:  93% 246/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.key.weight]
# Loading weights:  93% 246/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.key.weight]
# Loading weights:  94% 247/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.query.bias]
# Loading weights:  94% 247/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.query.bias]
# Loading weights:  94% 248/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.query.weight]
# Loading weights:  94% 248/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.query.weight]
# Loading weights:  94% 249/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.value.bias]
# Loading weights:  94% 249/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.value.bias]
# Loading weights:  95% 250/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.value.weight]
# Loading weights:  95% 250/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.attention.value.weight]
# Loading weights:  95% 251/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.output.dense.bias]
# Loading weights:  95% 251/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.output.dense.bias]
# Loading weights:  95% 252/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.output.dense.weight]
# Loading weights:  95% 252/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.attention.output.dense.weight]
# Loading weights:  96% 253/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.intermediate.dense.bias]
# Loading weights:  96% 253/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.intermediate.dense.bias]
# Loading weights:  96% 254/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.intermediate.dense.weight]
# Loading weights:  96% 254/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.intermediate.dense.weight]
# Loading weights:  97% 255/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_after.bias]
# Loading weights:  97% 255/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_after.bias]
# Loading weights:  97% 256/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_after.weight]
# Loading weights:  97% 256/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_after.weight]
# Loading weights:  97% 257/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_before.bias]
# Loading weights:  97% 257/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_before.bias]
# Loading weights:  98% 258/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_before.weight]
# Loading weights:  98% 258/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.layernorm_before.weight]
# Loading weights:  98% 259/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.output.dense.bias]
# Loading weights:  98% 259/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.output.dense.bias]
# Loading weights:  98% 260/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.output.dense.weight]
# Loading weights:  98% 260/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.encoder.layer.11.output.dense.weight]
# Loading weights:  99% 261/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.layernorm.bias]
# Loading weights:  99% 261/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.layernorm.bias]
# Loading weights:  99% 262/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.layernorm.weight]
# Loading weights:  99% 262/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.layernorm.weight]
# Loading weights: 100% 263/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.pooler.dense.bias]
# Loading weights: 100% 263/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.pooler.dense.bias]
# Loading weights: 100% 264/264 [00:00<00:00, 729.09it/s, Materializing param=encoder.pooler.dense.weight]
# Loading weights: 100% 264/264 [00:00<00:00, 694.80it/s, Materializing param=encoder.pooler.dense.weight]
# The tied weights mapping and config for this model specifies to tie decoder.bert.embeddings.word_embeddings.weight to decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie decoder.cls.predictions.bias to decoder.cls.predictions.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# MangaOcrModel LOAD REPORT from: kha-white/manga-ocr-base
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-18 14:30:50.259 | INFO     | manga_ocr.ocr:__init__:22 - Using CUDA
#
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:01<?, ?B/s]2026-03-18 14:30:52.200 | INFO     | manga_ocr.ocr:__init__:35 - OCR ready
#
# model.safetensors:   0% 0.00/444M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/444M [00:02<?, ?B/s]
# model.safetensors:   2% 8.33M/444M [00:02<00:10, 42.3MB/s]
# model.safetensors:  18% 79.1M/444M [00:02<00:02, 141MB/s]
# Processing pages...:   0% 1/2194 [00:20<12:37:41, 20.73s/it]
# model.safetensors:  63% 281M/444M [00:04<00:01, 142MB/s]
# model.safetensors: 100% 444M/444M [00:04<00:00, 94.2MB/s]
# Processing pages...: 100% 2194/2194 [31:42<00:00,  1.15it/s]
# 2026-03-18 15:02:33.796 | INFO     | mokuro.run:run:146 - Processed successfully: 1/1
